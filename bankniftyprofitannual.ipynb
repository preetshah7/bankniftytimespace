# %% [markdown]
# # BANK NIFTY ANNUAL PROFIT FOR A GIVEN VWAP FUNCTION
# ### - Preet Shah

# %% [markdown]
# ### IMPORT REQUIRED LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\users\zeels\anaconda3\lib\site-packages (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\zeels\anaconda3\lib\site-packages (2.6.1)
# Requirement already satisfied: et-xmlfile in c:\users\zeels\anaconda3\lib\site-packages (from openpyxl) (1.0.1)
# Requirement already satisfied: jdcal in c:\users\zeels\anaconda3\lib\site-packages (from openpyxl) (1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
data = pd.read_excel('BankNiftyFutures_Data5Min.xlsx')
data.head()
# Out:
#          Ticker       Date  Final Date format      Time      Open 5  \
# 0  BANKNIFTY_F1 2015-01-01           20150101  09:20:00  18861.3496
# 1  BANKNIFTY_F1 2015-01-01           20150101  09:25:00  18808.0000
# 2  BANKNIFTY_F1 2015-01-01           20150101  09:30:00  18826.9492
# 3  BANKNIFTY_F1 2015-01-01           20150101  09:35:00  18825.0508
# 4  BANKNIFTY_F1 2015-01-01           20150101  09:40:00  18805.0000
#
#        High 5       Low 5     Close 5  Volume 5  Year
# 0  18867.9492  18793.0000  18808.3496     84825  2015
# 1  18835.0000  18802.1992  18829.0000     40925  2015
# 2  18833.4004  18820.0000  18826.0996     27000  2015
# 3  18829.0996  18810.0000  18810.0000     18025  2015
# 4  18808.9492  18775.0000  18803.9492     60100  2015

# %% [markdown]
# ### INCLUDE='ALL' GIVES DESCRIPTION OF ALL COLUMNS

# %%
data.describe(include='all')
# Out:
#               Ticker                 Date  Final Date format      Time  \
# count          91737                91737       9.173700e+04     91737
# unique             1                 1226                NaN       450
# top     BANKNIFTY_F1  2018-07-17 00:00:00                NaN  09:36:00
# freq           91737                   75                NaN       329
# first            NaN  2015-01-01 00:00:00                NaN       NaN
# last             NaN  2019-12-31 00:00:00                NaN       NaN
# mean             NaN                  NaN       2.017057e+07       NaN
# std              NaN                  NaN       1.413046e+04       NaN
# min              NaN                  NaN       2.015010e+07       NaN
# 25%              NaN                  NaN       2.016033e+07       NaN
# 50%              NaN                  NaN       2.017063e+07       NaN
# 75%              NaN                  NaN       2.018092e+07       NaN
# max              NaN                  NaN       2.019123e+07       NaN
#
#               Open 5        High 5         Low 5       Close 5      Volume 5  \
# count   91737.000000  91737.000000  91737.000000  91737.000000  9.173700e+04
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# first            NaN           NaN           NaN           NaN           NaN
# last             NaN           NaN           NaN           NaN           NaN
# mean    22852.481723  22868.809964  22836.145490  22852.631275  5.531416e+04
# std      4816.167946   4818.059589   4814.411349   4816.300957  6.066659e+04
# min     13449.900400  13559.900400  13406.400400  13445.000000  0.000000e+00
# 25%     18506.000000  18522.250000  18490.099600  18506.150400  1.916000e+04
# 50%     23525.800800  23533.199200  23518.000000  23526.599600  3.565000e+04
# 75%     26805.050800  26820.650400  26786.150400  26805.000000  6.888000e+04
# max     32755.000000  32773.851600  32745.000000  32756.849600  1.580480e+06
#
#                 Year
# count   91737.000000
# unique           NaN
# top              NaN
# freq             NaN
# first            NaN
# last             NaN
# mean     2016.990952
# std         1.412742
# min      2015.000000
# 25%      2016.000000
# 50%      2017.000000
# 75%      2018.000000
# max      2019.000000

# %%
def calculateVwap(data):
    data['TP'] = (data['High 5']+data['Low 5']+data['Close 5'])/3.0
    data['TradedValue']  = data['TP']*data['Volume 5']
    data['CumVolume'] = data['Volume 5'].cumsum()
    data['CumTradedValue'] = data['TradedValue'].cumsum()
    data['VWAP'] = data['CumTradedValue'] /data['CumVolume']
    return data

calculateVwap(data)
#df = df.groupby('dt').apply(calculateVwap)
# Out:
#              Ticker       Date  Final Date format      Time      Open 5  \
# 0      BANKNIFTY_F1 2015-01-01           20150101  09:20:00  18861.3496
# 1      BANKNIFTY_F1 2015-01-01           20150101  09:25:00  18808.0000
# 2      BANKNIFTY_F1 2015-01-01           20150101  09:30:00  18826.9492
# 3      BANKNIFTY_F1 2015-01-01           20150101  09:35:00  18825.0508
# 4      BANKNIFTY_F1 2015-01-01           20150101  09:40:00  18805.0000
# 5      BANKNIFTY_F1 2015-01-01           20150101  09:45:00  18803.9492
# 6      BANKNIFTY_F1 2015-01-01           20150101  09:50:00  18821.0000
# 7      BANKNIFTY_F1 2015-01-01           20150101  09:55:00  18837.0000
# 8      BANKNIFTY_F1 2015-01-01           20150101  10:00:00  18846.9004
# 9      BANKNIFTY_F1 2015-01-01           20150101  10:05:00  18835.0508
# 10     BANKNIFTY_F1 2015-01-01           20150101  10:10:00  18852.0000
# 11     BANKNIFTY_F1 2015-01-01           20150101  10:15:00  18848.5508
# 12     BANKNIFTY_F1 2015-01-01           20150101  10:20:00  18835.6992
# 13     BANKNIFTY_F1 2015-01-01           20150101  10:25:00  18840.1504
# 14     BANKNIFTY_F1 2015-01-01           20150101  10:30:00  18843.7500
# 15     BANKNIFTY_F1 2015-01-01           20150101  10:35:00  18830.0000
# 16     BANKNIFTY_F1 2015-01-01           20150101  10:40:00  18830.5000
# 17     BANKNIFTY_F1 2015-01-01           20150101  10:45:00  18836.0000
# 18     BANKNIFTY_F1 2015-01-01           20150101  10:50:00  18830.1504
# 19     BANKNIFTY_F1 2015-01-01           20150101  10:55:00  18834.1992
# 20     BANKNIFTY_F1 2015-01-01           20150101  11:00:00  18846.0000
# 21     BANKNIFTY_F1 2015-01-01           20150101  11:05:00  18843.5000
# 22     BANKNIFTY_F1 2015-01-01           20150101  11:10:00  18845.0000
# 23     BANKNIFTY_F1 2015-01-01           20150101  11:15:00  18842.0000
# 24     BANKNIFTY_F1 2015-01-01           20150101  11:20:00  18840.0000
# 25     BANKNIFTY_F1 2015-01-01           20150101  11:25:00  18870.1992
# 26     BANKNIFTY_F1 2015-01-01           20150101  11:30:00  18870.0000
# 27     BANKNIFTY_F1 2015-01-01           20150101  11:35:00  18871.0508
# 28     BANKNIFTY_F1 2015-01-01           20150101  11:40:00  18860.0000
# 29     BANKNIFTY_F1 2015-01-01           20150101  11:45:00  18856.0000
# ...             ...        ...                ...       ...         ...
# 91714  1.686196e+08  5073619626    1.207747e+14  23804.447945
# 91715  2.932184e+08  5073628666    1.207750e+14  23804.463324
# 91716  1.572110e+09  5073677106    1.207766e+14  23804.545911
# 91717  3.081730e+08  5073686606    1.207769e+14  23804.562079
# 91718  2.264688e+08  5073693586    1.207771e+14  23804.573966
# 91719  5.896804e+08  5073711766    1.207777e+14  23804.604893
# 91720  3.120122e+08  5073721386    1.207780e+14  23804.621254
# 91721  3.523545e+08  5073732246    1.207784e+14  23804.639748
# 91722  2.646931e+08  5073740406    1.207786e+14  23804.653633
# 91723  2.107818e+09  5073805446    1.207807e+14  23804.763918
# 91724  7.700473e+08  5073829206    1.207815e+14  23804.804212
# 91725  4.303935e+08  5073842486    1.207819e+14  23804.826733
# 91726  9.276029e+08  5073871086    1.207829e+14  23804.875371
# 91727  4.747388e+08  5073885726    1.207833e+14  23804.900251
# 91728  3.340347e+08  5073896026    1.207837e+14  23804.917761
# 91729  3.631856e+08  5073907226    1.207840e+14  23804.936793
# 91730  3.023035e+09  5074000546    1.207871e+14  23805.094767
# 91731  1.603509e+09  5074050046    1.207887e+14  23805.178557
# 91732  6.121823e+08  5074068946    1.207893e+14  23805.210536
# 91733  8.685603e+08  5074095766    1.207901e+14  23805.255885
# 91734  4.165072e+09  5074224546    1.207943e+14  23805.472555
# 91735  2.597450e+09  5074304806    1.207969e+14  23805.607908
# 91736  1.627204e+09  5074355066    1.207985e+14  23805.692793
#
# [91737 rows x 15 columns]

# %% [markdown]
# ### COMBINE DATE AND TIME COLUMN USING PANDAS to_datetime FUNCTION

# %%
data.loc[:,'DT'] = pd.to_datetime(data.Date.astype(str)+' '+data.Time.astype(str))

# %%
data.head()
# Out:
#          Ticker       Date  Final Date format      Time      Open 5  \
# 0  BANKNIFTY_F1 2015-01-01           20150101  09:20:00  18861.3496
# 1  BANKNIFTY_F1 2015-01-01           20150101  09:25:00  18808.0000
# 2  BANKNIFTY_F1 2015-01-01           20150101  09:30:00  18826.9492
# 3  BANKNIFTY_F1 2015-01-01           20150101  09:35:00  18825.0508
# 4  BANKNIFTY_F1 2015-01-01           20150101  09:40:00  18805.0000
#
#        High 5       Low 5     Close 5  Volume 5  Year            TP  \
# 0  18867.9492  18793.0000  18808.3496     84825  2015  18823.099600
# 1  18835.0000  18802.1992  18829.0000     40925  2015  18822.066400
# 2  18833.4004  18820.0000  18826.0996     27000  2015  18826.500000
# 3  18829.0996  18810.0000  18810.0000     18025  2015  18816.366533
# 4  18808.9492  18775.0000  18803.9492     60100  2015  18795.966133
#
#     TradedValue  CumVolume  CumTradedValue          VWAP                  DT
# 0  1.596669e+09      84825    1.596669e+09  18823.099600 2015-01-01 09:20:00
# 1  7.702931e+08     125750    2.366962e+09  18822.763348 2015-01-01 09:25:00
# 2  5.083155e+08     152750    2.875278e+09  18823.423836 2015-01-01 09:30:00
# 3  3.391650e+08     170775    3.214443e+09  18822.678950 2015-01-01 09:35:00
# 4  1.129638e+09     230875    4.344081e+09  18815.725230 2015-01-01 09:40:00

# %%
data['DT'].head()
# Out:
# 0   2015-01-01 09:20:00
# 1   2015-01-01 09:25:00
# 2   2015-01-01 09:30:00
# 3   2015-01-01 09:35:00
# 4   2015-01-01 09:40:00
# Name: DT, dtype: datetime64[ns]

# %%
data['DT'] = pd.to_datetime(data['DT'])

# %% [markdown]
# ### SET THE COMBINED DATETIME COLUMN AS INDEX

# %%
data_2 = data.set_index('DT')
data_2.head()
# Out:
#                            Ticker       Date  Final Date format      Time  \
# DT
# 2015-01-01 09:20:00  BANKNIFTY_F1 2015-01-01           20150101  09:20:00
# 2015-01-01 09:25:00  BANKNIFTY_F1 2015-01-01           20150101  09:25:00
# 2015-01-01 09:30:00  BANKNIFTY_F1 2015-01-01           20150101  09:30:00
# 2015-01-01 09:35:00  BANKNIFTY_F1 2015-01-01           20150101  09:35:00
# 2015-01-01 09:40:00  BANKNIFTY_F1 2015-01-01           20150101  09:40:00
#
#                          Open 5      High 5       Low 5     Close 5  Volume 5  \
# DT
# 2015-01-01 09:20:00  18861.3496  18867.9492  18793.0000  18808.3496     84825
# 2015-01-01 09:25:00  18808.0000  18835.0000  18802.1992  18829.0000     40925
# 2015-01-01 09:30:00  18826.9492  18833.4004  18820.0000  18826.0996     27000
# 2015-01-01 09:35:00  18825.0508  18829.0996  18810.0000  18810.0000     18025
# 2015-01-01 09:40:00  18805.0000  18808.9492  18775.0000  18803.9492     60100
#
#                      Year            TP   TradedValue  CumVolume  \
# DT
# 2015-01-01 09:20:00  2015  18823.099600  1.596669e+09      84825
# 2015-01-01 09:25:00  2015  18822.066400  7.702931e+08     125750
# 2015-01-01 09:30:00  2015  18826.500000  5.083155e+08     152750
# 2015-01-01 09:35:00  2015  18816.366533  3.391650e+08     170775
# 2015-01-01 09:40:00  2015  18795.966133  1.129638e+09     230875
#
#                      CumTradedValue          VWAP
# DT
# 2015-01-01 09:20:00    1.596669e+09  18823.099600
# 2015-01-01 09:25:00    2.366962e+09  18822.763348
# 2015-01-01 09:30:00    2.875278e+09  18823.423836
# 2015-01-01 09:35:00    3.214443e+09  18822.678950
# 2015-01-01 09:40:00    4.344081e+09  18815.725230

# %% [markdown]
# ### DROP THE UNNECESSARY COLUMNS FROM THE DATAFRAME

# %%
data_2.drop(['Date'], axis=1, inplace=True)
data_2.drop(['Final Date format'], axis=1, inplace=True)
data_2.drop(['Time'], axis=1, inplace=True)
data_2.drop(['Year'], axis=1, inplace=True)

# %%
data_2.head(10)
# Out:
#                            Ticker      Open 5      High 5       Low 5  \
# DT
# 2015-01-01 09:20:00  BANKNIFTY_F1  18861.3496  18867.9492  18793.0000
# 2015-01-01 09:25:00  BANKNIFTY_F1  18808.0000  18835.0000  18802.1992
# 2015-01-01 09:30:00  BANKNIFTY_F1  18826.9492  18833.4004  18820.0000
# 2015-01-01 09:35:00  BANKNIFTY_F1  18825.0508  18829.0996  18810.0000
# 2015-01-01 09:30:00  56438.832667  1.977118e+09     554400    1.043380e+10
# 2015-01-01 09:45:00  56491.434267  1.498479e+09     847575    1.594938e+10
# 2015-01-01 10:00:00  56537.967467  8.914339e+08    1025950    1.931039e+10
# 2015-01-01 10:15:00  56521.266933  5.237666e+08    1140200    2.146336e+10
#
#                              VWAP
# DT
# 2015-01-01 09:15:00  37645.862948
# 2015-01-01 09:30:00  56461.828016
# 2015-01-01 09:45:00  56452.641304
# 2015-01-01 10:00:00  56465.735561
# 2015-01-01 10:15:00  56472.622769

# %%
data['DT'].head()
# Out:
# 0   2015-01-01 09:20:00
# 1   2015-01-01 09:25:00
# 2   2015-01-01 09:30:00
# 3   2015-01-01 09:35:00
# 4   2015-01-01 09:40:00
# Name: DT, dtype: datetime64[ns]

# %% [markdown]
# ### REMOVE THE COMBINED DATETIME COLUMN FROM INDEX COLUMN

# %%
df2.reset_index(inplace=True)
#df2 = df2.rename(columns = {'index':'DT'})
df2.head()
# Out:
#                    DT      Open 5      High 5       Low 5     Close 5  \
# 0 2015-01-01 09:15:00  37669.3496  37702.9492  37595.1992  37637.3496
# 1 2015-01-01 09:30:00  56457.0000  56471.4492  56405.0000  56440.0488
# 2 2015-01-01 09:45:00  56461.9492  56518.9512  56450.5508  56504.8008
# 3 2015-01-01 10:00:00  56533.9512  56560.8008  56510.3516  56542.7500
# 4 2015-01-01 10:15:00  56524.4004  56547.0000  56499.1504  56517.6504
#
#    Volume 5            TP   TradedValue  CumVolume  CumTradedValue  \
# 0    125750  37645.166000  2.366962e+09     210575    3.963632e+09
# 1    105125  56438.832667  1.977118e+09     554400    1.043380e+10
# 2     79575  56491.434267  1.498479e+09     847575    1.594938e+10
# 3     47300  56537.967467  8.914339e+08    1025950    1.931039e+10
# 4     27800  56521.266933  5.237666e+08    1140200    2.146336e+10
#
#            VWAP
# 0  37645.862948
# 1  56461.828016
# 2  56452.641304
# 3  56465.735561
# 4  56472.622769

# %% [markdown]
# ### CREATE NEW COLUMNS OF day, month, year, minute, hour FROM DATETIME VALUE

# %%
df2['day'] = df2['DT'].dt.day
df2['month'] = df2['DT'].dt.month
df2['year'] = df2['DT'].dt.year
df2['minute'] = df2['DT'].dt.minute
df2['hours'] = df2['DT'].dt.hour

df2.head()
# Out:
#                    DT      Open 5      High 5       Low 5     Close 5  \
# 0 2015-01-01 09:15:00  37669.3496  37702.9492  37595.1992  37637.3496
# 1 2015-01-01 09:30:00  56457.0000  56471.4492  56405.0000  56440.0488
# 2 2015-01-01 09:45:00  56461.9492  56518.9512  56450.5508  56504.8008
# 3 2015-01-01 10:00:00  56533.9512  56560.8008  56510.3516  56542.7500
# 4 2015-01-01 10:15:00  56524.4004  56547.0000  56499.1504  56517.6504
#
#    Volume 5            TP   TradedValue  CumVolume  CumTradedValue  \
# 0    125750  37645.166000  2.366962e+09     210575    3.963632e+09
# 1    105125  56438.832667  1.977118e+09     554400    1.043380e+10
# 2     79575  56491.434267  1.498479e+09     847575    1.594938e+10
# 3     47300  56537.967467  8.914339e+08    1025950    1.931039e+10
# 4     27800  56521.266933  5.237666e+08    1140200    2.146336e+10
#
#            VWAP  day  month  year  minute  hours
# 0  37645.862948    1      1  2015      15      9
# 1  56461.828016    1      1  2015      30      9
# 2  56452.641304    1      1  2015      45      9
# 3  56465.735561    1      1  2015       0     10
# 4  56472.622769    1      1  2015      15     10

# %% [markdown]
# ### CREATE NEW DATAFRAME USING ONLY USEFUL VALUES and CREATE NEW EMPTY COLUMNS

# %%
df3 = df2[['DT', 'Close 5', 'High 5', 'Low 5', 'VWAP', 'day', 'month', 'year', 'minute', 'hours']]
df3['close-VWAP'] = ''
df3['buy'] = ''
df3['sell'] = ''
df3.head()
# Out:
# C:\Users\zeels\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\zeels\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\zeels\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#                    DT     Close 5      High 5       Low 5          VWAP  day  \
# 0 2015-01-01 09:15:00  37637.3496  37702.9492  37595.1992  37645.862948    1
# 1 2015-01-01 09:30:00  56440.0488  56471.4492  56405.0000  56461.828016    1
# 2 2015-01-01 09:45:00  56504.8008  56518.9512  56450.5508  56452.641304    1
# 3 2015-01-01 10:00:00  56542.7500  56560.8008  56510.3516  56465.735561    1
# 4 2015-01-01 10:15:00  56517.6504  56547.0000  56499.1504  56472.622769    1
#
#    month  year  minute  hours close-VWAP buy sell
# 0      1  2015      15      9
# 1      1  2015      30      9
# 2      1  2015      45      9
# 3      1  2015       0     10
# 4      1  2015      15     10

# %% [markdown]
# ### FILL THE close-VWAP COLUMN WITH THE RESPECTIVE DIFFERENCES OF CLOSING VALUE AND CALCULATED VWAP

# %%
for i in range(0, len(df2)):
    df3['close-VWAP'][i] = df3['Close 5'][i] - df3['VWAP'][i]
df3.head()

# %% [markdown]
# ### NSE (National Stock Exchange) Tick Size is Rs. 0.05

# %%
tick = 0.05

# %%
plt.figure(figsize=(15,5))
plt.plot(df3['close-VWAP'])

# %% [markdown]
# ### DROP THE ROWS BEFORE 9:45 AM

# %%
count = 0
for i in range(0, len(df3)):
    
    if df3['hours'][i]==9 and (df3['minute'][i]==15 or df3['minute'][i]==30):
        count+=1
        df3.drop([i], inplace = True)
        
print(count)
df3.head()

# %%
df4 = df3.reset_index(level = None, drop= False, inplace = False, col_level=0)
df4.head()

# %% [markdown]
# ### COUNT THE TOTAL NUMBER OF TIMES CLOSING VALUE WAS HIGHER THAN VWAP

# %%
c=0
for i in range(0, len(df3)):
    if df4['close-VWAP'][i]>0:
        c+=1
print(c)

# %% [markdown]
# ### FILL UP THE BUY AND SELL VALUES WITH HIGH+TICK AND LOW-TICK RESPECTIVELY

# %%
for i in range(0, len(df3)):
    if df4['close-VWAP'][i]>0:
        df4['buy'][i] = df4['High 5'][i] + tick
        df4['sell'][i] = 0
    else:
        df4['buy'][i] = 0
        df4['sell'][i] = df4['Low 5'][i] - tick
df4.head()

# %% [markdown]
# ### USE THE FOLLOWING COMMAND TO SAVE THE DATASET FORMED ABOVE AS EXCEL FILE

# %%
#df4.to_excel('BankNiftyFutures_df4.xlsx')

# %% [markdown]
# ### USING MATPLOTLIB CREATE SCATTER PLOT OF BUY AND SELL DATA

# %%
plt.figure(figsize=(15,5))
plt.scatter(df4.index, df4['buy'], color='blue', s=3)
plt.scatter(df4.index, df4['sell'], color='red', s=3)
plt.legend(['buy', 'sell'])

# %%
df4['buy'].sum()

# %%
df4['sell'].sum()

# %% [markdown]
# ### NET VALUE ADDED FOR THE GIVEN DATASET

# %%
df4['sell'].sum() - df4['buy'].sum()

# %% [markdown]
# ### CREATE profit AND loss COLUMN FOR DAILY PROFIT AND LOSS

# %%
df4['profit'] = ''
df4['loss'] = ''

# %%
df4.head()

# %% [markdown]
# ### FILL PROFIT AS SELL-BUY and where profit is positive fill LOSS AS 0 AND VICE VERSA

# %%
for i in range(0, len(df4)):
    if (df4['sell'][i] - df4['buy'][i])>0:
        df4['profit'][i] = df4['sell'][i] - df4['buy'][i]
        df4['loss'][i] = 0
    elif (df4['sell'][i] - df4['buy'][i])<0:
        df4['profit'][i] = 0
        df4['loss'][i] = df4['buy'][i] - df4['sell'][i]

# %%
df4.head()

# %%
#df4.to_excel('BankNiftyFutures_df4_profit_loss.xlsx')

# %% [markdown]
# ### TOTAL PROFIT AND LOSS FOR THE ENTIRE DATASET

# %%
print('Profit:', df4['profit'].sum())
print('Loss:  ', df4['loss'].sum())

# %%
plt.figure(figsize=(15,5))
plt.scatter(df4['index'], df4['profit'], color = 'blue', s = 3)
plt.scatter(df4['index'], df4['loss'], color = 'red', s = 3)
plt.legend(['Profit', 'Loss'])

# %%
df4['year'].unique()

# %% [markdown]
# ### ANNUAL TOTAL PROFIT AND LOSS

# %%
p2015 = 0; p2016 = 0; p2017 = 0; p2018 = 0; p2019 = 0;
l2015 = 0; l2016 = 0; l2017 = 0; l2018 = 0; l2019 = 0;

for i in range(0, len(df4)):
    if df4['year'][i]==2015:
        p2015 += df4['profit'][i]
        l2015 += df4['loss'][i]
    elif df4['year'][i]==2016:
        p2016 += df4['profit'][i]
        l2016 += df4['loss'][i]
    elif df4['year'][i]==2017:
        p2017 += df4['profit'][i]
        l2017 += df4['loss'][i]
    elif df4['year'][i]==2018:
        p2018 += df4['profit'][i]
        l2018 += df4['loss'][i]
    elif df4['year'][i]==2019:
        p2019 += df4['profit'][i]
        l2019 += df4['loss'][i]

# %%
x = [1,2,3,4,5]
p = [p2015, p2016, p2017, p2018, p2019]
l = [l2015, l2016, l2017, l2018, l2019]

# %%
data = {'PROFIT':[p2015, p2016, p2017, p2018, p2019],
        'LOSS':[l2015, l2016, l2017, l2018, l2019]}

df = pd.DataFrame(data, index =['2015','2016','2017','2018','2019'])
df

# %%
plt.scatter(x,p, color='blue')
plt.scatter(x,l, color='red')

# %%
plt.plot(x,p,'o-',color='blue')
plt.plot(x,l,'o-',color='red')
plt.legend(['Profit', 'Loss'])
